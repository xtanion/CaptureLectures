# %%
import cv2
from PIL import Image
import imagehash
from skimage.metrics import structural_similarity
import numpy as np

# %%
capture=cv2.VideoCapture("video/demo0.mp4")

# %%
def similar(i):
    hash0 = imagehash.average_hash(Image.open('frame/'+str(i)+'.jpg')) 
    hash1 = imagehash.average_hash(Image.open('frame/'+str(i-1)+'.jpg')) 
    cutoff = 5
    if hash0 - hash1 < cutoff:
        return True
    else:
        return False

# %%
f, img1 = capture.read()
print(img1.shape)
# Out:
# (360, 640, 3)

# %% [markdown]
# i=0
# while(capture.isOpened()):
#
#      #vid_capture.read() methods returns a tuple, first element is a bool
#      #and the second is frame
#     flag,frame=capture.read()
#     if(flag==False):
#         break
#     path='frame/'+str(i)+'.jpg'
#     # 20 is in milliseconds, try to increase the value, say 50 and observe
# #     key = cv2.waitKey(3000)
#     cv2.imwrite(path,frame)
#     i+=1

# %%
def purge_duplicate(img0, img1, threshold=0.5, i=0):
    sim, diff = structural_similarity(img0, img1, full=True)
    path='frame/'+str(i)+'.jpg'
    if(sim < threshold):
        cv2.imwrite(path, img0)

# %%
i=0
# images = []
lag, frame=capture.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
i+=1
while(capture.isOpened()):
    print(i)
    print(frame.shape)
     #vid_capture.read() methods returns a tuple, first element is a bool
     #and the second is frame
    img0 = frame
    flag, frame=capture.read()
    #         if i==0:
#     cv2.imwrite('frame/'+str(i)+'.jpg',frame)
    if(flag==False):
        break

    # 20 is in milliseconds, try to increase the value, say 50 and observe
    # key = cv2.waitKey(3)
    # cv2.imwrite(path,frame)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    img1 = frame
    print(img1.shape)
    purge_duplicate(img0, img1, 0.8, i)
    i+=1
# Out:
# 1
# (360, 640)
# (360, 640)
# 2
# (360, 640)
# (360, 640)
# 3
# (360, 640)
# (360, 640)
# 4
# (360, 640)
# (360, 640)
# 5
# (360, 640)
# (360, 640)
# 6
# (360, 640)
# (360, 640)
# 7
# (360, 640)
# (360, 640)
# 8
# (360, 640)
# (360, 640)
# 9
# (360, 640)
# (360, 640)
# 10
# (360, 640)
# (360, 640)
# 11
# (360, 640)
# (360, 640)
# 12
# (360, 640)
# (360, 640)
# 13
# (360, 640)
# (360, 640)
# 14
# (360, 640)
# (360, 640)
# 15
# (360, 640)
# (360, 640)
# 16
# (360, 640)
# (360, 640)
# 17
# (360, 640)
# (360, 640)
# 18
# (360, 640)
# (360, 640)
# 19
# (360, 640)
# (360, 640)
# 20
# (360, 640)
# (360, 640)
# 21
# (360, 640)
# (360, 640)
# 22
# (360, 640)
# (360, 640)
# 23
# (360, 640)
# (360, 640)
# 24
# (360, 640)
# (360, 640)
# 25
# (360, 640)
# (360, 640)
# 26
# (360, 640)
# (360, 640)
# 27
# (360, 640)
# (360, 640)
# 28
# (360, 640)
# (360, 640)
# 29
# (360, 640)
# (360, 640)
# 30
# (360, 640)
# (360, 640)
# 31
# (360, 640)
# (360, 640)
# 32
# (360, 640)
# (360, 640)
# 33
# ...

# %%
print(len(images))

print(images[1].shape)
#comparing
purge_duplicate(images[250], images[280], 0.5)
# Out:
# 446
# (360, 640)

# %%
capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [8], in <module>
#       1 capture.release()
# ----> 2 cv2.destroyAllWindows()
#
# error: OpenCV(4.5.4) /tmp/pip-req-build-9vck9bv0/opencv/modules/highgui/src/window.cpp:1268: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'
